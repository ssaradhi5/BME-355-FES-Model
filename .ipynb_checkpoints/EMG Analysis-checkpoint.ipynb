# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import os
from scipy.signal import hilbert, savgol_filter

# %%
ta=[]
freq=[]
for path,dirs,files in os.walk('./EMG Raw Data'):
    for file in files:
        x=loadmat(os.path.join(path,file))
        ta.append(x['s']['Data'][0][0]['EMG'][0][0][0])
        freq.append(x['s']['EMGFreq'][0][0][0][0])
        print(file)
ta=np.array(ta)
freq=np.array(freq)
# Out:
# Subject16.mat
# Subject21.mat
# Subject24.mat
# Subject25.mat
# Subject27.mat
# Subject35.mat
# Subject37.mat
# Subject38.mat
# Subject48.mat
# C:\Users\harri\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   if __name__ == '__main__':

# %%
print(freq)
# Out:
# [ 960  960  800  960  960  960  960  960 1000]

# %%
fig,ax=plt.subplots(len(ta),figsize=(10,10))
minimum=len(ta[0])
for i,data in enumerate(ta):
    signal=np.abs((data))
    print(len(signal))
    if minimum>len(signal):
        minimum=len(signal)
    ax[i].plot(signal)
# Out:
# 1105
# 785
# 821
# 865
# 961
# 1041
# 849
# 801
# 1026

# %%
fig,ax=plt.subplots(len(ta),figsize=(10,10))
signals=[]
for i,data in enumerate(ta):
    signal=np.abs((data))
    signal=savgol_filter(signal,15,3)
    signals.append(signal)
    print(len(signal))
    ax[i].plot(signal)


# test=savgol_filter(np.abs(ta[0]),25,3)
# plt.plot(test)

signals=np.array(signals)
# Out:
# 1105
# 785
# 821
# 865
# 961
# 1041
# 849
# 801
# 1026
# C:\Users\harri\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
signals[0]
# Out:
# array([0.02174981, 0.04203396, 0.05936825, ..., 0.13376055, 0.08931705,
#        0.03068034])

# %%
# minimum
for i,signal in enumerate(signals):
    signals[i]=signals[i][50:minimum]
# len(signals[0][0:minimum])

# %%
fig,ax=plt.subplots(len(signals),figsize=(10,10))
# signals=[]
for i,signal in enumerate(signals):
    print(len(signal))
    ax[i].plot(signal)
# Out:
# 735
# 735
# 735
# 735
# 735
# 735
# 735
# 735
# 735

# %%
signal_mean=signals.mean(axis=0)
plt.plot(signal_mean)

# %%
signal_mean.shape
# Out:
# (735,)

# %%
from sklearn.preprocessing import scale
X = scale( signal_mean, axis=0, with_mean=True, with_std=True, copy=True )
# X=X.mean(axis=0)
X=(X-min(X))/(max(X)-min(X))
plt.plot(X)

# %%
X.shape
# Out:
# (735,)

# %%
# np.savetxt('EMG_data.csv',X,delimiter=",")

# %%
x['s']['Data'][0][0]['EMG']
# Out:
# array([[array([[-0.35034574, -0.42157492,  0.05767359, ...,  0.06348031,
#          0.06502878,  0.09270752],
#        [-0.01991788, -0.00094924,  0.02227767, ..., -0.00753019,
#         -0.01314336, -0.00830443],
#        [-0.01323473,  0.00186275,  0.01792804, ..., -0.0097507 ,
#         -0.00646022, -0.01052493],
#        ...,
#        [ 0.03059335,  0.0485942 ,  0.03910987, ...,  0.18408451,
#          0.16550296,  0.24118398],
#        [ 0.12152473,  0.06442526,  0.04835997, ..., -0.03390199,
#         -0.03351488, -0.06603255],
#        [-0.00062403, -0.00797922, -0.02307671, ..., -0.01881845,
#         -0.00914057, -0.00662432]]),
#         array([[-0.00293084, -0.00138237,  0.00229522, ..., -0.00273728,
#          0.00848906,  0.00365012],
#        [ 0.00859823,  0.00859823,  0.00298506, ..., -0.00359589,
#         -0.00456368, -0.00301522],
#        [-0.00016454, -0.00577771, -0.00771329, ...,  0.01338449,
#         -0.00364858, -0.00597127],
#        ...,
# ...

# %%
# foot_strike=x['s']['Data'][0][0]['TimeStampKin']
# emg_stamp=x['s']['Data'][0][0]['TimeStampEmg']

# x['s']['Data']

# %%
x['s']['Data'][0][0]['TimeStampKin']
# Out:
# array([[array([[2.8]]), array([[3.73333333]]), array([[3.03333333]]),
#         array([[2.13333333]]), array([[3.15]]), array([[3.26666667]]),
#         array([[3.25]]), array([[2.56666667]]), array([[2.05]]),
#         array([[2.46666667]]), array([[2.31666667]]), array([[3.4]]),
#         array([[3.81666667]]), array([[2.31666667]]),
#         array([[2.33333333]]), array([[1.88333333]])]], dtype=object)

# %%
emg_data=x['s']['Data'][0][0]['EMG']

# %%
tibalis_data=emg_data[0][0][0]

# %%
tibalis_data.shape
# Out:
# (1105,)

# %%
plt.plot(tibalis_data)

# %%
freq
# Out:
# 960

# %%
signal=np.abs((tibalis_data))

# %%
fig=plt.figure()
ax0=fig.add_subplot()
ax0.plot(tibalis_data[0:100])
ax0.plot(signal[0:100])

# %%
for dat

# %% [markdown]
# ## Regression Model

# %%
arr=[]
arr=[0.5 for i in range(10)]

# %%
arr
# Out:
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]

# %%
points=20
a=[0.01]
a=np.tile(a,20)
a
# Out:
# array([0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01])

# %%
test=[1]
test=np.linspace(0,5,20)
test
# Out:
# array([0.        , 0.26315789, 0.52631579, 0.78947368, 1.05263158,
#        1.31578947, 1.57894737, 1.84210526, 2.10526316, 2.36842105,
#        2.63157895, 2.89473684, 3.15789474, 3.42105263, 3.68421053,
#        3.94736842, 4.21052632, 4.47368421, 4.73684211, 5.        ])

# %%
from sklearn.metrics import mean_squared_error
old_mse=1000
# mse=mean_squared_error(a,test)
mse_list=[]

a=[0.01]
a=np.tile(a,20)
y=(0.01*a) +0.05 
best_mse=10000
index=[]
step_size=0.01

a_list=[]
for i in range(int(1/step_size)):
    mse=mean_squared_error(y,test)
    
    mse_list.append(mse)
    best_mse=min(mse_list)
    a_list.append(a[0])
    a=a+0.01
    y=(0.5*a) +0.5

# %%
y
# Out:
# array([1.005, 1.005, 1.005, 1.005, 1.005, 1.005, 1.005, 1.005, 1.005,
#        1.005, 1.005, 1.005, 1.005, 1.005, 1.005, 1.005, 1.005, 1.005,
#        1.005, 1.005])

# %%
best_mse
index=mse_list.index(best_mse)
print(index)
print(a_list[index])
# Out:
# 99
# 1.0000000000000007

# %%
# Out:
# 0.02

# %%
plt.plot(test)

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
X, y, coefficients = make_regression(
    n_samples=50,
    n_features=1,
    n_informative=1,
    n_targets=1,
    noise=5,
    coef=True,
    random_state=1
)

# %%
n = X.shape[1]
r = np.linalg.matrix_rank(X)

# %%
U, sigma, VT = np.linalg.svd(X, full_matrices=False)

# %%
D_plus = np.diag(np.hstack([1/sigma[:r], np.zeros(n-r)]))

# %%
V = VT.T
X_plus = V.dot(D_plus).dot(U.T)
w = X_plus.dot(y)
error = np.linalg.norm(X.dot(w) - y, ord=2) ** 2

# %%
lr = LinearRegression()
lr.fit(X, y)
w = lr.coef_[0]

# %%
plt.scatter(X, y)
plt.plot(X, w*X, c='red')
